# %%
# !pip install geopandas
# !pip install geopy
# !pip install folium

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import folium 
import csv
import pandas as pd

# %%
df = pd.read_csv("ghaziabad_wards.csv", encoding= 'unicode_escape')

print(df)
# Out:
#     Ward No.                       Ward
# 0          1         Bagu Krishna Nagar
# 1          2                Rahul Vihar
# 2          3            Old Vijay Nagar
# 3          4                Mata Colony
# 4          5                Gagan Vihar
# ..       ...                        ...
# 95        96            Nehru Nagar III
# 96        97                 Ramprastha
# 97        98               Ahinsa Khand
# 98        99            Vaibhav Khand I
# 99       100  Shipra Suncity Indirapura
#
# [100 rows x 2 columns]

# %%
df['Country'] = 'India'
df.head()
# Out:
#    Ward No.                Ward Country
# 0         1  Bagu Krishna Nagar   India
# 1         2         Rahul Vihar   India
# 2         3     Old Vijay Nagar   India
# 3         4         Mata Colony   India
# 4         5         Gagan Vihar   India

# %%
df['State'] = 'Ghaziabad'
df
# Out:
#     Ward No.                       Ward Country      State
# 0          1         Bagu Krishna Nagar   India  Ghaziabad
# 1          2                Rahul Vihar   India  Ghaziabad
# 2          3            Old Vijay Nagar   India  Ghaziabad
# 3          4                Mata Colony   India  Ghaziabad
# 4          5                Gagan Vihar   India  Ghaziabad
# ..       ...                        ...     ...        ...
# 95        96            Nehru Nagar III   India  Ghaziabad
# 96        97                 Ramprastha   India  Ghaziabad
# 97        98               Ahinsa Khand   India  Ghaziabad
# 98        99            Vaibhav Khand I   India  Ghaziabad
# 99       100  Shipra Suncity Indirapura   India  Ghaziabad
#
# [100 rows x 4 columns]

# %%
df["location"] = df['Ward'] +", " + df['State'] +", " + df['Country']
df
# Out:
#     Ward No.  ...                                     location
# 0          1  ...         Bagu Krishna Nagar, Ghaziabad, India
# 1          2  ...                Rahul Vihar, Ghaziabad, India
# 2          3  ...            Old Vijay Nagar, Ghaziabad, India
# 3          4  ...                Mata Colony, Ghaziabad, India
# 4          5  ...                Gagan Vihar, Ghaziabad, India
# ..       ...  ...                                          ...
# 95        96  ...            Nehru Nagar III, Ghaziabad, India
# 96        97  ...                 Ramprastha, Ghaziabad, India
# 97        98  ...               Ahinsa Khand, Ghaziabad, India
# 98        99  ...            Vaibhav Khand I, Ghaziabad, India
# 99       100  ...  Shipra Suncity Indirapura, Ghaziabad, India
#
# [100 rows x 5 columns]

# %%
from geopy.exc import GeocoderTimedOut 
from geopy.geocoders import Nominatim 
import numpy as np
   
# declare an empty list to store 
# latitude and longitude of values  
# of city column 
longitude = [] 
latitude = [] 
   
# function to find the coordinate 
# of a given city  
def findGeocode(location): 
       
    # try and catch is used to overcome 
    # the exception thrown by geolocator 
    # using geocodertimedout   
    try: 
          
        # Specify the user_agent as your 
        # app name it should not be none 
        geolocator = Nominatim(user_agent="Google Maps") 
          
        return geolocator.geocode(location) 
      
    except GeocoderTimedOut: 
          
        return findGeocode(location)     
  
# each value from city column 
# will be fetched and sent to 
# function find_geocode    
for i in (df["location"]): 
      
    if findGeocode(i) != None: 
           
        loc = findGeocode(i) 
          
        # coordinates returned from  
        # function is stored into 
        # two separate list 
        latitude.append(loc.latitude) 
        longitude.append(loc.longitude) 
       
    # if coordinate for a city not 
    # found, insert "NaN" indicating  
    # missing value  
    else: 
        latitude.append(np.nan) 
        longitude.append(np.nan)

# %%
df["Longitude"] = longitude 
df["Latitude"] = latitude 

df
# Out:
#     Ward No.                       Ward  ...  Longitude   Latitude
# 0          1         Bagu Krishna Nagar  ...        NaN        NaN
# 1          2                Rahul Vihar  ...  77.407360  28.638784
# 2          3            Old Vijay Nagar  ...  77.423343  28.648167
# 3          4                Mata Colony  ...  77.420285  28.647046
# 4          5                Gagan Vihar  ...        NaN        NaN
# ..       ...                        ...  ...        ...        ...
# 95        96            Nehru Nagar III  ...  77.374238  28.627239
# 96        97                 Ramprastha  ...  77.320805  28.658290
# 97        98               Ahinsa Khand  ...        NaN        NaN
# 98        99            Vaibhav Khand I  ...        NaN        NaN
# 99       100  Shipra Suncity Indirapura  ...        NaN        NaN
#
# [100 rows x 7 columns]

# %%
df['Latitude']= df['Latitude'].fillna(0)
df['Longitude']= df['Longitude'].fillna(0)
df
# Out:
#     Ward No.                       Ward  ...  Longitude   Latitude
# 0          1         Bagu Krishna Nagar  ...   0.000000   0.000000
# 1          2                Rahul Vihar  ...  77.407360  28.638784
# 2          3            Old Vijay Nagar  ...  77.423343  28.648167
# 3          4                Mata Colony  ...  77.420285  28.647046
# 4          5                Gagan Vihar  ...   0.000000   0.000000
# ..       ...                        ...  ...        ...        ...
# 95        96            Nehru Nagar III  ...  77.374238  28.627239
# 96        97                 Ramprastha  ...  77.320805  28.658290
# 97        98               Ahinsa Khand  ...   0.000000   0.000000
# 98        99            Vaibhav Khand I  ...   0.000000   0.000000
# 99       100  Shipra Suncity Indirapura  ...   0.000000   0.000000
#
# [100 rows x 7 columns]

# %%
df.to_csv("ghaziabad.csv")

# %%
from folium import plugins
from folium.plugins import HeatMap


map_hooray = folium.Map(location=[28.60004, 77.300042], zoom_start = 13) 

# Ensure you're handing it floats
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] = df['Longitude'].astype(float)

# Filter the DF for rows, then columns, then remove NaNs
heat_df = df[['Latitude', 'Longitude']]
heat_df = heat_df.dropna(axis=0, subset=['Latitude','Longitude'])

# List comprehension to make out list of lists
heat_data = [[row['Latitude'],row['Longitude']] for index, row in heat_df.iterrows()]

# Plot it on the map
HeatMap(heat_data).add_to(map_hooray)

# Display the map
map_hooray
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitude = 28.60004
longitude = 77.300042
ghaziabad_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# %%
for lat, lon, ward in zip(df['Latitude'], df['Longitude'], df['Ward']):
    folium.CircleMarker(
        [lat, lon],
        popup = ('Ward: ' + str(ward).capitalize()
                ),
        color='blue',
        key_on = ward,
        threshold_scale=[0,1,2,3],
        fill=True,
        fill_opacity=0.7
        ).add_to(ghaziabad_map)
ghaziabad_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
